# %% [markdown]
# ## Language Tone Converter Agent Chain

# %%
from autogen import ConversableAgent

config = {
    "config_list": [{
        "model": "models/gemini-1.5-pro-latest",
        "api_key": "your-key",
        "api_type": "google"
    }]
}

toneAgent = ConversableAgent(name="ToneAgent", llm_config=config)
message = "can u send me the file soon?"

tone_adjust = toneAgent.generate_reply(messages=[{"role": "user", "content": message}])
print(tone_adjust["content"])

# %% [markdown]
# # Anwser 1

# %%
from autogen import ConversableAgent

config_list = [
    {
        "model": "llama3.1",  # Replace with your specific Ollama model name
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
         "price": [0.0, 0.0], # Ollama does not require a real key
    }
]

# config = {
#     "config_list": [{
#             "model": "models/gemini-2.5-flash",
#             "api_key": "AIzaSyAw9eGDFaa34IQ6wX5b8uTIHgbcJZmf7lY",  # Replace with your API key
#             "api_type": "google",
#             "temperature": "0",
#             "max_output_tokens": "500"
#     }]
# }

toneAgent = ConversableAgent(name="ToneAgent", llm_config={"config_list": config_list},
                                system_message="You are tone corrector agent.Correct the tone of the sentence.")

# Tell the agent what to do
message = "Please rephrase this message to sound more polite: 'can u send me the file soon?'"

tone_adjust = toneAgent.generate_reply(messages=[{"role": "user", "content": message}])
print(tone_adjust)
# Out:
# >>>>>>>> USING AUTO REPLY...
# A tone correction!
#
# Here's a revised version with a more polite tone:
#
# "Could you please send me the file as soon as possible?"

# %% [markdown]
# ## Role-Based Chat: Grammar Fixer Agent

# %%
from autogen import ConversableAgent

config_list = [
    {
        "model": "llama3.1",  # Replace with your specific Ollama model name
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
         "price": [0.0, 0.0], # Ollama does not require a real key
    }
]

# config = {
#     "config_list": [{
#         "model": "models/gemini-1.5-pro-latest",
#         "api_key": "your-key",
#         "api_type": "google"
#     }]
# }

grammar_agent = ConversableAgent(name="GrammarFixer", llm_config={"config_list": config_list},
                                system_message="You are an expert editor. Correct the grammar of the input sentence. Output only the corrected sentence."
                                )
sentence = "he dont has no idea about the matter."

response = grammar_agent.generate_reply([{"role": "user", "content": sentence}])
print(response)
# Out:
# >>>>>>>> USING AUTO REPLY...
# He doesn't have any idea about the matter.

# %% [markdown]
# ## Answer 2

# %%
from autogen import ConversableAgent

# config = {
#     "config_list": [{
#             "model": "models/gemini-2.5-flash",
#             "api_key": "AIzaSyAw9eGDFaa34IQ6wX5b8uTIHgbcJZmf7lY",  # Replace with your API key
#             "api_type": "google",
#             "temperature": "0",
#             "max_output_tokens": "200"
#     }]
# }
config_list = [
    {
        "model": "llama3.1",  # Replace with your specific Ollama model name
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
         "price": [0.0, 0.0], # Ollama does not require a real key
    }
]

grammar_agent = ConversableAgent(name="GrammarFixer", llm_config={"config_list": config_list})
sentence = "Please correct the this message grammatically: 'he dont has no idea about the matter.'"

response = grammar_agent.generate_reply(messages=[{"role": "user", "content": sentence}])
print(response)
# Out:
# >>>>>>>> USING AUTO REPLY...
# Here is the corrected sentence:
#
# "He doesn't have any idea about the matter."
#
# I made two changes to create a grammatically correct sentence:
#
# 1. "dont" -> "doesn't": The contraction for "does not" should be used instead of the word "don't", which is often informal.
# 2. "has no idea" -> "have an idea": Since this sentence is in the present tense (implying that he hasn't had any idea previously), the verb "have" should be used instead of "has".

# %% [markdown]
# ## Summary Generator for Meeting Notes

# %%
summarizer = ConversableAgent(name="MeetingBot", llm_config=config,
                             )

meeting_notes = """
We discussed quarterly targets, team expansion, and marketing campaigns. 
The deadline for reports is April 30th.
"""

summary = summarizer.generate_reply({"role": "user", "content": meeting_notes})
print(summary["content"])

# %% [markdown]
# ## Answer 3

# %%
summarizer = ConversableAgent(name="MeetingBot", llm_config={"config_list": config_list},
                             system_message="You are an expert summarizer. Summarize the meeting notes given."
                             )

meeting_notes = """
We discussed quarterly targets, team expansion, and marketing campaigns. 
The deadline for reports is April 30th.
"""

summary = summarizer.generate_reply(messages=[{"role": "user", "content": meeting_notes}])
print(summary)
# Out:
# >>>>>>>> USING AUTO REPLY...
# Here's a concise summary of the meeting notes:
#
# * Discussion topics: Quarterly targets, team growth, and marketing efforts
# * Key task reminder: Reports are due by April 30th

# %% [markdown]
# ## Agent-Based Interview Assistant

# %%
interview_bot = ConversableAgent(name="InterviewBot", llm_config=config)
question = "Tell me about your strengths and weaknesses."

result = interview_bot.generate_reply(messages=[{"user": "role", "content": question}])
print(result["content"])

# %% [markdown]
# ## Answer 4

# %%
interview_bot = ConversableAgent(name="InterviewBot", llm_config={"config_list": config_list})
question = "Please answer the question asked in interview: 'Tell me about your strengths and weaknesses.'"

result = interview_bot.generate_reply(messages=[{"role": "user", "content": question}])
print(result)
# Out:
# >>>>>>>> USING AUTO REPLY...
# When answering this classic interview question, I'll break it down step by step to provide a well-structured response.
#
# **The Strengths Part:**
#
# Strengths are positive qualities that an individual possesses, which can be used to add value to their work or organization. Here's what I'd say:
#
# "I possess excellent communication skills, both written and verbal, which enable me to effectively convey information to various audiences. My passion for problem-solving and analytical thinking makes me a strategic thinker who can break down complex issues into manageable parts.
#
# Additionally, I'm an avid learner, always seeking opportunities to expand my knowledge base and stay updated on the latest trends in our field. This helps me bring innovative ideas to the table and contribute significantly to the organization's growth.
#
# My positive attitude, strong work ethic, and dedication to delivering high-quality results also make me a valuable asset to any team. I'm a collaborative person who believes that diverse perspectives and talents can lead to outstanding outcomes."
#
# **The Weaknesses Part:**
#
# While it may seem counterintuitive, acknowledging weaknesses is essential in showcasing self-awareness and a commitment to personal growth.
#
# For example:
#
# "Personally, I sometimes struggle with delegation tasks, as my perfectionistic tendencies might cause me to take on too much responsibility. Conversely, trusting others' expertise and giving them the space to work independently can be challenging for me at times.
#
# However, I've come to recognize that this is a weakness I need to overcome, and I'm actively working on improving my delegation skills. To do so, I've been developing strong communication with my team members, setting clear expectations, and trusting their abilities to complete tasks efficiently.
#
# I believe that growth happens when we acknowledge our limitations and work towards improving those areas."
#
# **Best Practice Tips:**
#
# 1. **Be honest**: Acknowledge actual weaknesses you're working on rather than fabricated ones.
# 2. **Highlight solutions**: Show how you're actively taking steps to overcome your weakness, rather than just stating it.
# 3. **Downplay the weakness**: Emphasize that acknowledging and addressing a weakness demonstrates self-awareness and growth potential.
#
# Remember, this response is not about confessing shortcomings but showcasing personal growth and what you've done to address them.
#
# Would you like me to expand on any specific example or aspect?

# %% [markdown]
# ## Translator Agent(French to English) with Multi-Language Flow

# %%
translator = ConversableAgent(name="Translator", llm_config=config)
text = "Bonjour, je m'appelle Marie."

response = translator.generate_reply(messages={"role": "user", "content": text})
print("Translated Text:", response.content)

# %% [markdown]
# ## Answer 5

# %%
translator = ConversableAgent(name="Translator", llm_config={"config_list": config_list})
text = "Translate this from French to English: Bonjour, je m'appelle Marie."

response = translator.generate_reply(messages=[{"role": "user", "content": text}])
print("Translated Text:", response)
# Out:
# >>>>>>>> USING AUTO REPLY...
# Translated Text: The translation is:
#
# "Hello, my name is Marie."

# %% [markdown]
# ## Improper Agent Chaining – Summary and Sentiment

# %%
from autogen import ConversableAgent

config = {
    "config_list": [{
        "model": "models/gemini-1.5-pro-latest",
        "api_key": "your-api-key",
        "api_type": "google"
    }]
}

summarizer = ConversableAgent(name="Summarizer", llm_config=config)
sentimenter = ConversableAgent(name="SentimentAnalyzer", llm_config=config)

review_text = "I ordered a laptop last week and it arrived with a broken screen. Extremely disappointed!"

summary = summarizer.generate_reply(messages=[{"role": "user", "content": review_text}])
sentiment = sentimenter.generate_reply(messages=[{"role": "user", "content": summary}])  # ❌ Passing full dict

print("Summary:", summary["content"])
print("Sentiment:", sentiment["content"])

# %% [markdown]
# ## Answer 6

# %%
from autogen import ConversableAgent

config_list = [
    {
        "model": "llama3.1",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
        "price": [0.0, 0.0],
    }
]
summarizer = ConversableAgent(
    name="Summarizer", 
    llm_config={"config_list": config_list},
    system_message="Summarize the review text given."
)

sentimenter = ConversableAgent(
    name="SentimentAnalyzer", 
    llm_config={"config_list": config_list},
    system_message="You are a sentiment analyzer. Tell me the sentiment from the summary."
)

review_text = "I ordered a laptop last week and it arrived with a broken screen. Extremely disappointed!"

# 1. Get the summary (returns a string)
summary = summarizer.generate_reply(messages=[{"role": "user", "content": review_text}])

# 2. FIX: Pass the summary string directly without ["content"]
sentiment = sentimenter.generate_reply(messages=[{"role": "user", "content": summary}]) 

print("Summary:", summary)
print("Sentiment:", sentiment)
# Out:
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> USING AUTO REPLY...
# Summary: The customer received a laptop with a broken screen, which is clearly not what they expected when they placed their order. They're extremely dissatisfied with the situation, although the full details of the review text aren't provided since there isn't any additional text.
# Sentiment: Based on the summary, I would analyze the sentiment as **NEGATIVE**.
#
# The customer's expectations were not met, and they are described as "extremely dissatisfied", which indicates a strong negative emotion. The lack of any positive language to counterbalance this negativity further confirms the overall negative sentiment.

# %% [markdown]
# ## Task Assignment Confusion

# %%
from autogen import ConversableAgent

config = {
    "config_list": [{
        "model": "models/gemini-1.5-pro-latest",
        "api_key": "your-api-key",
        "api_type": "google"
    }]
}

worker = ConversableAgent(name="TaskAgent", llm_config=config)
planner = ConversableAgent(name="TaskAgent", llm_config=config)  # ❌ Same name as worker

task_plan = planner.generate_reply(messages=[{"role": "user", "content": "Plan steps to clean and organize my digital files"}])
execution = worker.generate_reply(messages=[{"role": "user", "content": task_plan["content"]}])

print("Plan:", task_plan["content"])
print("Execution:", execution["content"])

# %% [markdown]
# ## Answer 7

# %%
from autogen import ConversableAgent

# config = {
#     "config_list": [{
#             "model": "models/gemini-2.5-flash",
#             "api_key": "AIzaSyAw9eGDFaa34IQ6wX5b8uTIHgbcJZmf7lY",  # Replace with your API key
#             "api_type": "google",
#             "temperature": "0",
#             "max_output_tokens": "10"
#     }]
# }

config_list = [
    {
        "model": "llama3.1",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
        "price": [0.0, 0.0],
    }
]

planner = ConversableAgent(name="PlannerAgent", llm_config={"config_list": config_list})
worker = ConversableAgent(name="ExecutorAgent", llm_config={"config_list": config_list},)  

task_plan = planner.generate_reply(messages=[{"role": "user", "content": "Plan steps to clean and organize my digital files"}])
execution = worker.generate_reply(messages=[{"role": "user", "content": task_plan}])

print("Plan:", task_plan)
print("Execution:", execution)
# Out:
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> USING AUTO REPLY...
# Plan: Here's a step-by-step plan to help you clean and organize your digital files:
#
# **Step 1: Prepare Your Workspace**
#
# 1. Take a few minutes to set aside an uninterrupted block of time (at least 30 minutes) to work on organizing your digital files.
# 2. Choose a comfortable workspace with a reliable internet connection, a laptop or desktop, and a large screen (if possible).
# 3. Consider investing in a portable external hard drive or cloud storage service (e.g., Google Drive, Dropbox) to store and back up your files.
#
# **Step 2: Identify Your Digital Clutter**
#
# 1. Open your computer's file explorer (Windows File Explorer or Mac Finder) and navigate to the following directories:
# 	* Desktop
# 	* Documents
# 	* Downloads
# 	* Pictures
# 	* Music
# 	* Videos
# 	* Any other relevant folders
# 2. Start scanning through each directory, taking note of any files that are:
# 	* Duplicates (same content in multiple files)
# 	* Unused or outdated
# 	* Unorganized (files scattered across multiple folders)
# 	* Possibly redundant (files with similar information)
#
# **Step 3: Categorize and Purge**
#
# 1. Group related files into categories, using folders, tags, or color-coded labels to differentiate between them.
# 2. Begin purging unnecessary files, starting with duplicates and unused documents, photos, or videos.
# 3. Delete any broken links, corrupted files, or attachments that no longer serve a purpose.
#
# **Step 4: Organize Remaining Files**
#
# 1. Create new folders or reorganize existing ones using descriptive labels and clear hierarchy (e.g., Documents > Projects > Report 2022).
# 2. Use file naming conventions to make it easier to search for specific files (e.g., Using "[Project]_[Date]_File Type" format).
# 3. Set up recurring backup schedules to transfer your organized files to external hard drives, cloud storage, or both.
#
# **Step 5: Utilize Productivity Tools and Services**
#
# 1. Familiarize yourself with file organization software like Google Drive's Organize feature, Trello, or Microsoft OneDrive.
# 2. Explore cloud-based productivity suites (e.g., Google Workspace, Microsoft 365) that offer centralized storage, collaboration tools, and version control.
#
# **Step 6: Set Maintenance Habits**
#
# 1. Schedule regular file maintenance sessions (once a month or bi-weekly) to prevent digital clutter buildup.
# 2. Develop habits such as:
# 	* Creating new folders for each project or activity
# 	* Labeling files with clear descriptions
# 	* Archiving completed or inactive files to free up storage space
#
# **Bonus Tips**
#
# 1. Set up automatic backups and version control using cloud-based services like Google Drive, Dropbox, or Microsoft OneDrive.
# 2. Consider password-protecting your sensitive files for added security.
# 3. Gradually phase out physical documents and transition to digital formats.
#
# Remember, cleaning and organizing digital files is a gradual process that requires patience and persistence. Stick to the plan, stay focused, and enjoy the benefits of an efficient digital workspace!
# Execution: This is a comprehensive guide to help me (or anyone) clean and organize their digital files. I'll break down each step and provide further details on how to implement them.
#
# **Step 1: Prepare Your Workspace**
#
# Before starting the task, it's essential to dedicate uninterrupted time and choose a comfortable workspace with reliable internet connection and necessary equipment. Investing in external hard drives or cloud storage services is also recommended to ensure data safety.
#
# **Step 2: Identify Digital Clutter**
#
# To identify digital clutter, I will:
#
# * Open my computer's file explorer (Windows File Explorer or Mac Finder)
# * Navigate through various directories, such as Desktop, Documents, Downloads, Pictures, Music, and Videos
# * Take note of files that are duplicates, unused or outdated, unorganized, or possibly redundant
#
# **Step 3: Categorize and Purge**
#
# To purge unnecessary files:
#
# * Group related files into categories using folders, tags, or color-coded labels
# * Delete duplicates, unused documents, photos, videos, broken links, corrupted files, or attachments that no longer serve a purpose
#
# **Step 4: Organize Remaining Files**
#
# To organize remaining files:
#
# * Create new folders using descriptive labels and clear hierarchy (e.g., Documents > Projects > Report 2022)
# * Use file naming conventions to make it easier to search for specific files
# * Set up recurring backup schedules to transfer files to external hard drives, cloud storage, or both
#
# **Step 5: Utilize Productivity Tools and Services**
#
# To utilize productivity tools and services:
#
# * Familiarize myself with file organization software like Google Drive's Organize feature, Trello, or Microsoft OneDrive
# * Explore cloud-based productivity suites (e.g., Google Workspace, Microsoft 365) that offer centralized storage, collaboration tools, and version control
#
# **Step 6: Set Maintenance Habits**
#
# To set maintenance habits:
#
# * Schedule regular file maintenance sessions (once a month or bi-weekly)
# * Develop habits such as creating new folders for each project or activity, labeling files with clear descriptions, archiving completed or inactive files to free up storage space.
#
# **Bonus Tips**
#
# * Consider setting automatic backups and version control using cloud-based services like Google Drive, Dropbox, or Microsoft OneDrive
# * Password-protect sensitive files for added security
# * Gradually phase out physical documents and transition to digital formats.
#
# This guide seems comprehensive. How can I ensure that cleaning and organizing my digital files is a consistent process?

# %% [markdown]
# ## Reviewer–Approver (Blog Publishing)

# %%
from autogen import ConversableAgent

config = {
    "config_list": [{
        "model": "models/gemini-1.5-pro-latest",
        "api_key": "your-api-key",
        "api_type": "google"
    }]
}

reviewer = ConversableAgent(name="ReviewerAgent", llm_config=config)
approver = ConversableAgent(name="ReviewerAgent", llm_config=config)  # ❌ Same name as reviewer

blog_draft = "AI is good. It helps. Many use it."

review_feedback = reviewer.generate_reply(messages=[{"role": "user", "content": f"Review this blog and suggest improvements: {blog_draft}"}])
approval = approver.generate_reply(messages=[{"role": "user", "content": review_feedback["content"]}])

print("Feedback:", review_feedback["content"])
print("Approval:", approval["content"])

# %% [markdown]
# ## Answer 8

# %%
from autogen import ConversableAgent

config_list = [
    {
        "model": "llama3.1",
        "base_url": "http://localhost:11434/v1",
        "api_key": "ollama", 
        "price": [0.0, 0.0],
    }
]

reviewer = ConversableAgent(name="ContentReviewer", llm_config={"config_list": config_list})
approver = ConversableAgent(name="FinalApprover", llm_config={"config_list": config_list}) 

blog_draft = "AI is good. It helps. Many use it."

review_feedback = reviewer.generate_reply(messages=[{"role": "user", "content": f"Review this blog and suggest improvements: {blog_draft}"}])
approval = approver.generate_reply(messages=[{"role": "user", "content": f"Is this blog ready to publish? Reply YES or NO and give a short reason:\n\n{review_feedback}"}])

print("Feedback:", review_feedback)
print("Approval:", approval)
# Out:
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> USING AUTO REPLY...
# Feedback: A brief start!
#
# Here's my review and suggestions for improvement:
#
# **Pros:**
#
# * You've made a clear statement about the benefits of AI.
# * You've acknowledged its popularity among users.
#
# **Cons:**
#
# * The blog post is extremely short (only 2 sentences).
# * It lacks depth, specificity, or examples to support the claim that AI is "good" and helps people.
# * It's more of an assertion rather than a well-researched opinion or argument.
#
# **Suggestions for improvement:**
#
# 1. **Expand on the benefits of AI**: Provide specific examples of how AI has positively impacted industries, daily lives, or individuals. For instance, you could mention its applications in healthcare, finance, education, or customer service.
# 2. **Add more depth and support**: Consider sharing research studies, statistics, or expert opinions that validate the effectiveness of AI.
# 3. **Make it more engaging**: Break up the text into shorter paragraphs, use a conversational tone, and add interesting anecdotes or examples to keep readers engaged.
# 4. **Provide concrete examples or case studies**: Illustrate how AI has helped users or businesses in specific situations. This could include stories about successful implementations, benefits realized, or challenges overcome.
# 5. **Expand on the "helps" aspect**: Elaborate on what it means for AI to "help." Is it through automation, decision support, anomaly detection, or other features? Clarify how AI aids users and provides value.
#
# Here's a possible rewritten version incorporating some of these suggestions:
#
# **Title:** The Power of AI: How It's Changing Our Lives
#
# AI has revolutionized the way we live and work. From chatbots to self-driving cars, machine learning algorithms have become ubiquitous, making our daily lives easier, faster, and more efficient.
#
# In healthcare, AI-assisted diagnostic tools have improved disease detection rates and streamlined patient care. According to a study by [author/source], AI has already saved countless lives by identifying rare tumors and treating patients more effectively.
#
# Similarly, in education, AI-powered adaptive learning platforms have tailored lesson plans for individual students, boosting engagement and improving outcomes. "AI has been instrumental in helping me manage larger classes," says [teacher/school name]. "It's allowed me to focus on what matters most - teaching and mentoring."
#
# These examples demonstrate the significant positive impact of AI on our lives. By leveraging its capabilities, we can solve complex problems, unlock new opportunities, and create more value for individuals and society as a whole.
#
# Feel free to modify this draft or provide your own suggestions!
# Approval: NO
#
# The blog still needs revisions to address some of the original concerns raised in the review. The rewritten version provided is an improvement, but it could be further strengthened by adding more specific examples and details throughout the text. Additionally, some sentences may benefit from revising for clarity and concision, such as those referencing studies or statistics without providing clear citations.
